# %%
#Problema 1.
fecha_hoy= input("fecha de hoy (dia-mes-año)")
print(fecha_hoy)
fecha_nacimiento= input("¿Cuando naciste? (dia-mes-año)")
print(fecha_nacimiento)
if fecha_hoy == fecha_nacimiento :
    print("hoy es tu cumpleaños.🥳")
else:
    print("todavia falta para tu cumpleaños.😉 ")
# Out:
# 06-03-2024
# 21-12-2005
# todavia falta para tu cumpleaños.😉

# %%
#Problema 2
n1= int(input("ingresa un número: "))
n2= int(input("ingresa otro número"))
res_n1 = n1*5
res_n2 = n2+3
print (f"{n1}*5={n2}+3")
print(f"{n1}*5={res_n1}")
print(f"{ n2}+3={res_n2}")
if res_n1==res_n2:
    print("los resultados son iguales")
else:
    print("los resultados son diferentes")
# Out:
# 1*5=2+3
# 1*5=5
# 2+3=5
# los resultados son iguales

# %%
#Problema 3
codigo_postal= int(input("ingresa tu codogo postal: "))
if 50000 <=codigo_postal <= 50030:
    print("puedes enviar cosas ya que se encuentra dento de rango ")
else:
    print("no puedes enviar cosas.🙁")
# Out:
# no puedes enviar cosas.🙁
